# %% [markdown]
# <span type="title">Histroy、Neurons and Neuroglia</span> | <span type="update">2018-09-17</span> - Version <span type="version">1.1</span>
#
#
# <span type="intro"><p class="card-text">本章对于神经科学有一个简要的介绍，并且对于神经元和神经胶质细胞进行了主要的讲解。</p></span>

# %% [markdown]
# # Histroy
#
# 古代人对于大脑的认识来自于观察。手具有手的形状，很容易猜想是用于抓握的，脚有脚的形状，可以看出是用于奔跑的。那么，对于大脑，比较统一的观点是，大脑包含软的和硬的两部分，其中和眼睛、耳朵等感觉器官在一起，因此软的对应感觉中心 scese center，而硬的则对应于运动控制，因为人们通过解剖得到，大脑中存在很多水分，因此笛卡尔等人比较推崇液压-机械理论，认为大脑通过对于液压的改变来控制运动 hydraumatic-machine throry。
#
# 对于大脑结构的划分定义了一些解剖学上的术语，这些术语沿用至今：
#
# 神经系统分为 CNS 中央神经系统 和 边缘神经系统，对于前者，包含大、小脑、脑干、脊髓。
#
# 大脑中外部包含了一层厚厚的灰质 gray matter，里面包裹了一层白质 white matter，对于 gray matter 上的突起部分，称之为 gyri，对于沟壑，称之为 sulci，对于裂，称之为 fissure。因此，大脑在解剖学上被分为 lobe 叶。对于解剖学的研究催生了 phrenology 颅相学。
#
# 自从解剖学以来，人们首先关注的是信号的传递问题，因为化学和物理的发展，人们逐渐认识到大脑并非通过水的压力，而是通过电信号传递的。nerve fiber 神经纤维是关注的重点。当时人们关注的主要问题是，fiber 是单向、双向还是复合的？因为剪短神经，导致感觉和运动能力的丧失，因此早期人们认为 nerve fiber 是双向的。但是随后，人们发现，fiber 在大部分时候是单向复合的，在脊髓位置分开了，通过对于此处 fiber 的实验证明了这个结论，即 fiber 是单向、复合并且通过电信号传递的，此外，在需要的时候，fiber 会将复合的信号通路分开输送到不同的部分。
#
# 随后人们对于特殊案例的分析，得到了一些有趣的结论，比如 Broca 发现颞叶附近损伤，可听但是不可说。后人也发现枕叶和视觉有关。
#
# 下一个阶段是确定神经的基本单位问题，是否存在单个 nerve cell，以及其组成的 nerve net？ schwann 发明了显微镜，并且提出了细胞学说。而后人根据显微镜观察，定义了 nerve cell。
#
# 神经科学研究的层次主要有以下六层：
#
# - Molecule 分子神经科学层面
#
# - Cell 细胞神经科学层面
#
# 这一层面主要解决分子是如何协作并且构成细胞的，神经细胞的分类以及它们如何形成了神经网络。
#
# - System 系统神经科学层面
#
# 这一层面主要解决系统性的神经细胞协作发挥特定功能问题，比如视觉系统回路和运动系统回路。
#
# - Behavior 行为神经科学层面
#
# 这一层面主要解决系统是如何协作来改变人类行为的。
#
# - Congition 认知神经科学层面
#
# 这一层面主要解决个体意识、语言、自我是如何形成并且如何工作的这一问题。

# %% [markdown]
# # Nerons
#
# 神经元和神经胶质细胞组成了神经系统的大部分结构。其中神经元约有1000亿个，而神经胶质细胞越有10000亿个。由于信号是在神经元中进行传递的，因此人们对于神经元的关注更多。但是近年以来，人们发现神经胶质细胞作用也非常复杂。
#
# 神经元细胞的直径约为 0.01 - 0.05 mm 左右，神经元细胞很软，因此需要通过甲醛浸泡来硬化，其可以通过以下方式进行染色观察：
#
# - Nissl stain 这种染色方法只能够染色细胞核
#
# - Golgi stain 这种染色方法可以将整个神经元染色
#
# 其中神经元的结构如下：
#
# - cell body 细胞体
#
# - soma(somata) 胞体
#
# - perikaryon(perikarya) 核周体
#
# - neurite 神经突起
#
# neurite 是区分神经细胞和别的细胞的关键所在。其中分为：
#
# - axon 树突，长度可达1m
#
# - dendrite 轴突，长度一般小于2mm
#
#
#
#
#
# 围绕着神经元是通过连接还是接触这一问题，人们提出了争论，认为神经元通过接触的这一派提出了 neuron doctrine 神经元学说，并且在很晚之后电子显微镜发明后才得以被证明。这是因为神经元之间的间距很小，nm级别，而神经元本身是um级别的大小，因此难以观察。
#
# ## Soma Structure
#
# 对于 soma，其结构包含有
#
# - nucleus 细胞核，直径 5-10um
#     - chromosome 染色体
#         - DNA 双螺旋结构，螺旋直径 2nm
# - cytosol 细胞液
# - cytoplasm 细胞质
# - organelle 细胞器
#
# 其中，对于DNA而言，其存在于 chromosome 中，而 chromosome 存在于 双层膜的 nucleus 中，后者包含核孔，用于 信使 mRNA 从 DNA 上采集遗传信息，并且进出细胞核。
#
# mRNA 采集 DNA 的遗传信息称之为 transcription 转录，之后结合 amino acid 形成 pro 的过程，称之为 translate 翻译。
#
# 翻译进行的位置在于 roughER 粗面内质网上，在这里，ribosome 核糖体被 mRNA 利用（作为宿主），通过 amino acid 氨基酸原料，对比 mRNA 上的遗传物质来合成 pro 蛋白质。除了基本的 ribosome 核糖体以外，还有 polyribosome 游离核糖体，其多个排成线，用于一个 mRNA 的翻译工作。区别于 ribosome，polyribosome 的工作产生的 pro 主要供给细胞质，而 ribosome 产生的 pro 主要用于细胞膜、细胞器等特殊用途。和 roughER 相对应的是 smothER，光滑内质网用于调节细胞质的浓度。
#
# 内质网生成的 pro 被 golgi apparatus 高尔基体截获，并进行分类。此外，常见的细胞器还有 mitochondrion，其将 pro，sugar，fat 氧化成为丙酮酸，并且结合氧气，参与 adp - atp 的氧化过程，放出二氧化碳，并且生成 atp 通用能量单位。
#
# 细胞骨架是维持细胞形状的重要组成部分， cytoskeleton 包含以下部分：
#
# - microtubule 20mm的微管，其主要由MAPs蛋白构成，多串蛋白聚合形成管道，神经细胞的信号可以改变聚合物形状，以改变细胞的形状。
#
# - microfilament 5nm的微丝，主要由肌纤蛋白组成，像绳子一样扭曲多股成为微丝，可以通过信号改变形状。
#
# - neurofilament 10nm的神经丝，像绳子一样扭曲形成，其中每个扭曲的部分由三个并行的亚结构组成。区别于微丝，神经丝机械强度更强，结构更坚固。
#
# ## Axon Structure
#
# 神经细胞具有 neurite 神经突起，因此特别不同，其中 axon 轴突最为特别。轴突由  axon hillock 轴丘起始，经过细长的 axon，到达 axon terminal 轴突末端。其中轴突不含 roughER，只有少数的 polyribosome 核糖体，并且其膜上的 pro 和 soma 上不同，被用作长距离的信息传输。轴突的长度约为1mm-1m，变化区间很大，其直径在人中约为1-25um，而在乌贼中可达1mm，直径越宽，传输速率越高。
#
# axon 在 axon terminal 之前，可能产生分支，称之为 axon collateral。
#
# axon terminal 轴突末端又称之为突触 synapse，其用于神经细胞的连接 innervatation。 对于 terminal/synapse 而言，这里没有 microtubule 微管，但是含有大量的 synaptic vesicle 囊泡、pro 蛋白质、 mitochondrion 线粒体，说明信号传输需要耗费大量能量，并且是化学方式进行的。
#
# axon terminal 有顺序，称之为 synapse 前段和 synapse 末端，其中 synapse 前段指的一般是 terminal，而后端指的一般是 axon dendritic 的 spine。这个单向的结构使用电-化学-电的方式进行信号传送。
#
# 其中 synapse cleft 突触间隙中进行的是 synapse transmission，传送的物质是 neurotransmitter 神经递质。
#
# 由于 axon terminal 不含有 roughER，因此不能自己合成 pro，其所需的物质从 soma 运送过来，通过 axon进行。在 axon 中，microtubule 充当滑轨，kinesin 充当滑杆， pro 通过固定在 kinesin 蛋白上，通过 atp 供能以输送到 terminal 上。这个过程称之为顺向运输，anterograde transport。此外，还有 retrograde transport，是通过 dynein 蛋白进行的，主要用于请求发送信号之类的目的。
#
# 在研究中，可以通过脯氨酸来染色 anterograde transport 过程，观察顺向传送。也可以通过 HRP 辣根过氧化物酶来染色 retrograde transport 过程，观察逆向传送，需要注意，对于狂犬病毒、口腔疤疹病毒，多通过 retrograde transport 方式进入 soma 中，从而影响神经活动，这多见于身体和情感应激反应的时候出现。
#
# ## Dendritic Structure
#
# dendritic 树突和 axon 有很大的区别，其中最主要的区别是， dendritic 长度为 mm 级别，其主要用于信号的接受。
#
# dendritic tree 是对于 dendritic 整体外观的描述， dendritic spine 指的是那些用于 接受 synapse 的位点，其中一个 spine 大约可接受两个 synapse 后端，接受 axon treminal 发送的信号。
#
# dendritic 包含一定的 polyribsome 在 spine 下面，此外还有大量的 cytosketon 和 mitochondrion 用于供能和维持结构形状。
#
# ## Nerve Cell Catagories
#
# 神经元的分类可以按照其 neurite 的多寡分类，比如：
#
# - unipolar neuron 单极神经细胞
# - bipolar neuron 双极神经细胞
# - multipolar neuron 大多数脑内的神经细胞都是多极神经细胞
#
# 此外，还可以根据是否有树突来划分，比如
#
# - spiny neuron 比如 pyramidal cell 椎体细胞
# - aspinous neuron 比如 stellate cell 星形细胞
#
# 此外，还可以按照功能划分
#
# - primary sensory neuron
# - motor neuron
# - interneuron 按照这种划分方法，大多数都是中间神经元
#
# 此外，还可以按照轴突长度划分，比如
#
# - golgi type i neuron 投射神经元
# - golgi type ii neuron 局部环路神经元（长）

# %% [markdown]
# # Neuroglia
#
# ## general function of glia
#
# - participates in neuron circuit formation and synaptic plasticity
#
# - make myelin
#
# - support the metabolic and signaling functions of neurons
#
# - contribute to formation of blood-brain barrier
#
# - participate in inflammatory response in injured neural tissure, like phagocytosis of cellular debris
#
# - contribute to the formation of scar tissure in damaged neural tissue
#
#
# ## astrocytes
#
# 神经胶质细胞有 astrocyte 星型胶质细胞，主要存在于 gray matter 中，更多的参与 synapses 和 neuronal cell body 的相关工作。
#
# 其主要作用有 提供 soma 胞体 钾离子的浓度调节（**ionic balance of extracellular fluids**），提供对于 synapse cleft 中的 neurotransmitter 多余的神经递质的处理，其细胞膜含有对于这些 transmitter 处理的 pro 蛋白质（remove and process **neurotransmitter** in synapse cleft）。此外，astrocyte 参与 synapses 的形成、血脑屏障、脑室屏障、受伤后的 neurons 恢复。 （formation of new synapses, contribute to formation of **blood-brain barrier and brain-ependymal barrier**. contribute to the **formation of scars that fill-in small spaces** that have been cleared of necrotic neural tissure following injury.）
#
# ## oligodendrocytes
#
# 此外，成髓鞘胶质细胞 oligodendroglial cell （少突胶质细胞）和 schwann cell 负责CNS和外周神经系统的 axon 的 myelin 髓鞘保护（主要是这些neuroglia的细胞质），除了少数部分的 axon 不受保护，这种情况称之为 node of ranvier。
#
# 对于 oligodendrocyte 而言，其主要作用是： **form myelin** in the CNS (Most of oligodendrocyte have been found in white matter).
#
# **the function of myelin:**
#
# - insulate by generating layer of membrane that wrap around a segment of an axon, **decreases the ionic leakness** of the axonal membrane
#
# - gaps between myelin segments, called "nodes of ranvier", allow for the **economical concentration of ion channels and ion pumps** that are necessary for electrical signaling in axons.
#
# 除此之外，oligodendrocyte **present antigens** that influence the outgrowth of axons in developing and recovering brain, but unfortunately, subject to **immunological attack** in centain diseases of the CNS.
#
# ## microglia
#
# 此外，还有 microglial cell 小胶质细胞，用于吞噬死亡或者退化的神经元以及其残渣。
#
# microglia is a special type of **mononuclear phagocyte** that resides in the CNS, it derived primarily from hematopoietic precursor cells that migrate into the brain during development.
#
# microglia exists in one of two forms: amoeboid and ramified.
#
# the ramified form is the dormant state. the amoeboid form is the activated, mobile state when microglia cells are engaged in phagocytic activity. activated microglia secrete signaling molecules that modulate local inflammatory responses in injured tissue.
#
# ## glial stem cell
#
# glial stem cell may give rise to more stem cells, mature astrocytes or oligodendrocytes or mature neurons.
#
# (glial stem cell exists in white matter)
#
# ## ependymocytes
#
# ependymal cell 室管膜细胞，在脑发育过程中指导细胞迁移。
#
# - capacity to generate new brain cells (perhaps even neurons) following injury (eg. stroke)
#
# ## brain-blood barrier
#
# bbb is specialized permeability barrier **between the capillary endothelium and the extracellular space in neural tissue**.
#
# - formed by tight junctions between **capillary endothelial cells**. surrounded by **end-feet processes of astrocytes**
#
# - exclude **large, water soluble molecules** from freely diffusing into CNS.
#
# - some molecules, such as **glucose and certain amino acids**, are transported passive or actively across the capillary endothelium.
#
# 血脑屏障亦阻止了很多有用的药剂，比如 dopamine 多巴胺进入神经细胞。

# %% [markdown]
# # Specifiction of Location
#
# 大脑的位置描述如下：对于上下左右，分别称之为 superior, inferior, anterior, posterior。（头顶部、头底部、头前部、头后部）。
#
# 这四个位置另有别称： superior = medial, inferior = lateral, anterior = rostral, posterior = caudal. 不过，这并不是完整的一一对应，rostral并非anterior的绝对水平，而是约有30度夹角，medial和rostral垂直，anterior和superior垂直。
#
# 此外，大脑的背侧和腹侧指的是上半部分和下半部分，dorsal = forebrain，ventral = hindbrain。此外，脊髓外侧（靠近背部）也称之为dorsal，而靠近喉咙部位称之为 ventral。
#
# 大脑的三个轴，其中横切面称之为 horizontal（又称之为axon的面），冠状面是平行于面部的面，称之为 coronal/frontal，而矢状面称之为 sagittal。
